# %%
# https://www.tensorflow.org/tutorials/generative/autoencoder
import tensorflow as tf
from tensorflow import keras

# %%
# mnist = keras.datasets.fashion_mnist
# (X_train_full, y_train_full), (X_test, y_test) = mnist.load_data()
mnist = keras.datasets.mnist
(X_train_full, y_train_full), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
import numpy as np
import matplotlib.pyplot as plt

print('X shape: ' + repr(X_train_full.shape) , ' - type: ' + str(X_train_full.dtype))
print('y shape: ' + repr(y_train_full.shape) , ' - type: ' + str(X_train_full.dtype))

tmpidxs = np.random.permutation( X_train_full.shape[0] )[:9]

plt.clf()
for i in range(9):
    plt.subplot(3,3,i+1)
    tmp_idx = tmpidxs[i]
    plt.imshow(X_train_full[tmp_idx,:,:], cmap='gray_r')
    plt.title('Showing a ' + str( y_train_full[tmp_idx] ) )
plt.show()
# Out:
# X shape: (60000, 28, 28)  - type: uint8
# y shape: (60000,)  - type: uint8

# %%
# also readjust range to float 0-1 for gradient descend training

X_valid, X_train = X_train_full[:5000]/255., X_train_full[5000:]/255.
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]
X_test = X_test/255.

# %%
def plot_image(image):
    plt.imshow(image, cmap='binary')
    plt.axis('off')

def show_reconstruction(model, X, n_images=5):
    reconstruction_idxs = np.random.permutation(np.arange(X.shape[0]))[:n_images]
    reconstructions = model.predict(X[reconstruction_idxs])
    fig = plt.figure(figsize=(n_images*1.5, 3))
    for image_index in range(n_images):
        plt.subplot(2, n_images, 1 + image_index)
        plot_image(X[reconstruction_idxs[image_index]])
        plt.subplot(2, n_images, 1 + image_index + n_images)
        plot_image( reconstructions[image_index] )

# %%
latent_size = 10

encoder = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28,28]),
    keras.layers.Dense(150, activation='selu'),
    keras.layers.Dense(100, activation='selu'),
])

latent = keras.models.Sequential([
    keras.layers.Dense(latent_size)
])

decoder = keras.models.Sequential([
    keras.layers.Dense(100, activation='selu'),
    keras.layers.Dense(150, activation='selu'),
    keras.layers.Dense(28*28, activation='sigmoid'),
    keras.layers.Reshape([28, 28])
])

simple_ae = keras.models.Sequential([encoder, latent, decoder])

encoder.summary()
latent.summary()
decoder.summary()
simple_ae.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 150)               117750
#
#  dense_1 (Dense)             (None, 100)               15100
#
# =================================================================
# Total params: 132,850
# Trainable params: 132,850
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 1,010
# Trainable params: 1,010
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 100)               1100
#
#  dense_4 (Dense)             (None, 150)               15150
#
#  dense_5 (Dense)             (None, 784)               118384
#
#  reshape (Reshape)           (None, 28, 28)            0
#
# =================================================================
# Total params: 134,634
# Trainable params: 134,634
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 100)               132850
#
#  sequential_1 (Sequential)   (None, 10)                1010
#
#  sequential_2 (Sequential)   (None, 28, 28)            134634
#
# =================================================================
# Total params: 268,494
# Trainable params: 268,494
# Non-trainable params: 0
# _________________________________________________________________

# %%
def rounded_accuracy(y_true, y_pred):
    return keras.metrics.binary_accuracy(tf.round(y_true), tf.round(y_pred))

simple_ae.compile(loss='binary_crossentropy',
              optimizer='adam', # try sgd
              metrics=[rounded_accuracy])

# %%
history = simple_ae.fit(X_train, X_train, validation_data=(X_valid, X_valid), 
                      epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.1144 - rounded_accuracy: 0.9571 - val_loss: 0.1119 - val_rounded_accuracy: 0.9588
# Epoch 2/10
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.1117 - rounded_accuracy: 0.9588 - val_loss: 0.1107 - val_rounded_accuracy: 0.9595
# Epoch 3/10
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.1104 - rounded_accuracy: 0.9596 - val_loss: 0.1092 - val_rounded_accuracy: 0.9604
# Epoch 4/10
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.1093 - rounded_accuracy: 0.9603 - val_loss: 0.1087 - val_rounded_accuracy: 0.9607
# Epoch 5/10
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.1084 - rounded_accuracy: 0.9609 - val_loss: 0.1078 - val_rounded_accuracy: 0.9613
# Epoch 6/10
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.1077 - rounded_accuracy: 0.9613 - val_loss: 0.1079 - val_rounded_accuracy: 0.9615
# Epoch 7/10
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.1069 - rounded_accuracy: 0.9618 - val_loss: 0.1067 - val_rounded_accuracy: 0.9622
# Epoch 8/10
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.1063 - rounded_accuracy: 0.9622 - val_loss: 0.1066 - val_rounded_accuracy: 0.9622
# Epoch 9/10
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.1058 - rounded_accuracy: 0.9625 - val_loss: 0.1060 - val_rounded_accuracy: 0.9624
# Epoch 10/10
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.1052 - rounded_accuracy: 0.9629 - val_loss: 0.1054 - val_rounded_accuracy: 0.9631

# %%
show_reconstruction(simple_ae, X_valid)

# %%
# random input does not work
random_input = np.random.rand(1, latent_size)
y = decoder.predict( random_input )
plot_image(y[0,:,:])

# %%
# check what the latent output is for some samples
encoder_latent = keras.models.Sequential([encoder, latent])

# %%
y = encoder_latent.predict( X_valid[:1000, :,:] )
y.shape
# Out:
# (1000, 10)

# %%
plot_image(y[:50,:])

# %%
plt.plot(np.mean(y, axis=0))
plt.plot(np.std(y, axis=0))

# %%
# let's run the "average" input through the generative part of the network
m = np.mean( y, axis=0 )
mi = decoder.predict( np.reshape( m , (1,m.size) ) )
plot_image(mi[0,:,:])

# %%
# let's run one specific input through the generative part of the network
p = y[414,:]
pi = decoder.predict( np.reshape( p , (1,p.size) ) )
plot_image(pi[0,:,:])

# %%
# what if we sample randomly from the latent distribution, considering it normal?
c = np.cov(y.T)
n = np.random.multivariate_normal( np.mean(y, axis=0), c )
n = decoder.predict( np.reshape( n , (1,n.size) ) )
plot_image(n[0,:,:])
# run it multiple times - some results work, but many are nonsense or blurry

# %%
# variational autoencoder
K = keras.backend
kl_divergence = keras.losses.kullback_leibler_divergence

class Sampling(keras.layers.Layer):
    def call(self, inputs):
        mean, log_var = inputs
        return K.random_normal(tf.shape(log_var))*K.exp(log_var/2) + mean


codings_size = 10

# encoder
inputs = keras.layers.Input(shape=[28, 28])
z = keras.layers.Flatten()(inputs)
z = keras.layers.Dense(150, activation='selu')(z)
z = keras.layers.Dense(100, activation='selu')(z)

codings_mean = keras.layers.Dense(codings_size)(z)
codings_log_var = keras.layers.Dense(codings_size)(z)
codings = Sampling()([codings_mean, codings_log_var])

variational_encoder = keras.Model(
    inputs=[inputs], outputs=[codings_mean, codings_log_var, codings]
)

# decoder
decoder_inputs = keras.layers.Input(shape=[codings_size])
x = keras.layers.Dense(100, activation='selu')(decoder_inputs)
x = keras.layers.Dense(150, activation='selu')(x)
x = keras.layers.Dense(28*28, activation='sigmoid')(x)
outputs = keras.layers.Reshape([28, 28])(x)

variational_decoder = keras.Model(
    inputs=[decoder_inputs], outputs=[outputs]
)

# %%

_, _, codings = variational_encoder( inputs )
reconstructions = variational_decoder( codings )
variational_ae = keras.Model(inputs=[inputs], outputs=[reconstructions])

# %%
# losses
latent_loss = -0.5*K.sum(
    1 + codings_log_var - K.exp(codings_log_var) - K.square(codings_mean),
    axis=-1)
variational_ae.add_loss( K.mean(latent_loss)/784. )
variational_ae.compile(loss='binary_crossentropy', optimizer='adam',
                       metrics=[rounded_accuracy])

# %%
history = variational_ae.fit(X_train, X_train, epochs=10, batch_size=128,
                             validation_data=(X_valid, X_valid))
# Out:
# Epoch 1/10
# 430/430 [==============================] - 8s 17ms/step - loss: 0.2219 - rounded_accuracy: 0.9051 - val_loss: 0.1797 - val_rounded_accuracy: 0.9308
# Epoch 2/10
# 430/430 [==============================] - 7s 16ms/step - loss: 0.1718 - rounded_accuracy: 0.9355 - val_loss: 0.1646 - val_rounded_accuracy: 0.9392
# Epoch 3/10
# 430/430 [==============================] - 7s 16ms/step - loss: 0.1618 - rounded_accuracy: 0.9414 - val_loss: 0.1579 - val_rounded_accuracy: 0.9435
# Epoch 4/10
# 430/430 [==============================] - 7s 17ms/step - loss: 0.1564 - rounded_accuracy: 0.9446 - val_loss: 0.1536 - val_rounded_accuracy: 0.9465
# Epoch 5/10
# 430/430 [==============================] - 7s 16ms/step - loss: 0.1530 - rounded_accuracy: 0.9468 - val_loss: 0.1505 - val_rounded_accuracy: 0.9482
# Epoch 6/10
# 430/430 [==============================] - 7s 16ms/step - loss: 0.1507 - rounded_accuracy: 0.9483 - val_loss: 0.1491 - val_rounded_accuracy: 0.9493
# Epoch 7/10
# 430/430 [==============================] - 7s 16ms/step - loss: 0.1490 - rounded_accuracy: 0.9494 - val_loss: 0.1475 - val_rounded_accuracy: 0.9505
# Epoch 8/10
# 430/430 [==============================] - 7s 16ms/step - loss: 0.1476 - rounded_accuracy: 0.9504 - val_loss: 0.1462 - val_rounded_accuracy: 0.9512
# Epoch 9/10
# 430/430 [==============================] - 7s 17ms/step - loss: 0.1463 - rounded_accuracy: 0.9512 - val_loss: 0.1448 - val_rounded_accuracy: 0.9522
# Epoch 10/10
# 430/430 [==============================] - 7s 17ms/step - loss: 0.1454 - rounded_accuracy: 0.9518 - val_loss: 0.1443 - val_rounded_accuracy: 0.9524

# %%
def plot_multiple_images(images, n_cols=None):
    n_cols = n_cols or len(images)
    n_rows = (len(images) - 1) // n_cols + 1
    if images.shape[-1] == 1:
        images = np.squeeze(images, axis=-1)
    plt.figure(figsize=(n_cols, n_rows))
    for index, image in enumerate(images):
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(image, cmap="binary")
        plt.axis("off")

# %%
codings = tf.random.normal(shape=[12, codings_size])
images = variational_decoder(codings).numpy()
plot_multiple_images(images, n_cols=3)

# %%
codings_grid = tf.reshape(codings, [1,3,4, codings_size])
larger_grid = tf.image.resize(codings_grid, size=[5, 7])
interpolated_codings = tf.reshape(larger_grid, [-1, codings_size])
images = variational_decoder(interpolated_codings).numpy()
plot_multiple_images(images, n_cols=7)
